# %% [markdown]
# # Encrypted Inference-Linear Regression

# %% [markdown]
# Encrypted Inference is the process of performing inference with machine learning models such that model owner cannot observe the true input data nor can the data owner see the true model weights. The weights and data are encrypted by splitting them into shares and performiming computations according to a protocol. The general class of methods know as Secure Multi Party Computation (SMPC).
#
# SOURCE: https://github.com/OpenMined/SyMPC/blob/main/examples/Encrypted-Inference-LinearRegression.ipynb

# %% [markdown]
# ### Imports

# %%
#External libraries
import pandas as pd
import numpy as np
import time

#Import torch
import torch
import torch.nn as nn
import torch.utils.data as data_utils
torch.manual_seed(0)

#Import syft
import syft as sy
sy.logger.remove()

# %% [markdown]
# ### Data Loading and Processing

# %%
#Download Boston housing dataset
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data
# Out:
# --2021-09-28 21:02:37--  https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252, 52.35.62.125, 128.200.200.146
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49082 (48K) [application/x-httpd-php]
# Saving to: ‘housing.data.1’
#
# housing.data.1      100%[===================>]  47.93K  69.3KB/s    in 0.7s
#
# 2021-09-28 21:02:38 (69.3 KB/s) - ‘housing.data.1’ saved [49082/49082]

# %%
#Import dataset and add headers
dataset=pd.read_csv("housing.data",delim_whitespace=True,
                    names=["crim","zn","indus",
                           "chas","nox","rm",
                           "age","dis","rad",
                           "tax","ptratio","black",
                           "lstat","medv"])

# %%
#Visualize and look at columns and rows of dataset
dataset.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
#Split data into features and target variables
features = dataset.drop("medv",axis=1)
targets = dataset["medv"]

# %%
#Normalize features
features = features.apply(
    lambda x: (x - x.mean()) / x.std()
)

# %%
features
# Out:
#          crim        zn     indus      chas       nox        rm       age  \
# 0   -0.419367  0.284548 -1.286636 -0.272329 -0.144075  0.413263 -0.119895
# 1   -0.416927 -0.487240 -0.592794 -0.272329 -0.739530  0.194082  0.366803
# 2   -0.416929 -0.487240 -0.592794 -0.272329 -0.739530  1.281446 -0.265549
# 3   -0.416338 -0.487240 -1.305586 -0.272329 -0.834458  1.015298 -0.809088
# 4   -0.412074 -0.487240 -1.305586 -0.272329 -0.834458  1.227362 -0.510674
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.412820 -0.487240  0.115624 -0.272329  0.157968  0.438881  0.018654
# 502 -0.414839 -0.487240  0.115624 -0.272329  0.157968 -0.234316  0.288648
# 503 -0.413038 -0.487240  0.115624 -0.272329  0.157968  0.983986  0.796661
# 504 -0.407361 -0.487240  0.115624 -0.272329  0.157968  0.724955  0.736268
# 505 -0.414590 -0.487240  0.115624 -0.272329  0.157968 -0.362408  0.434302
#
#           dis       rad       tax   ptratio     black     lstat
# 0    0.140075 -0.981871 -0.665949 -1.457558  0.440616 -1.074499
# 1    0.556609 -0.867024 -0.986353 -0.302794  0.440616 -0.491953
# 2    0.556609 -0.867024 -0.986353 -0.302794  0.396035 -1.207532
# 3    1.076671 -0.752178 -1.105022  0.112920  0.415751 -1.360171
# 4    1.076671 -0.752178 -1.105022  0.112920  0.440616 -1.025487
# ..        ...       ...       ...       ...       ...       ...
# 501 -0.625178 -0.981871 -0.802418  1.175303  0.386834 -0.417734
# 502 -0.715931 -0.981871 -0.802418  1.175303  0.440616 -0.500355
# 503 -0.772919 -0.981871 -0.802418  1.175303  0.440616 -0.982076
# 504 -0.667776 -0.981871 -0.802418  1.175303  0.402826 -0.864446
# 505 -0.612640 -0.981871 -0.802418  1.175303  0.440616 -0.668397
#
# [506 rows x 13 columns]

# %%
targets
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
#Convert features and targets into torch tensors
features = torch.tensor(features.values.astype(np.float32)) 
targets = torch.tensor(targets.values.astype(np.float32))

# %%
#Hyperparameters
batch_size = 16
epochs = 300
train_test_split = 0.8
lr = 0.001

# %%
train_indices=int(len(features)*train_test_split)

train_x = features[:train_indices]
train_y = targets[:train_indices]

test_x = features[train_indices+1:]
test_y = targets[train_indices+1:]

# %%
def get_batches(X, y):
    batches = []
    for index in range(0,len(train_x)+1,batch_size):
        batches.append((X[index:index+batch_size],y[index:index+batch_size]))
    
    return batches

# %%
train_batches = get_batches(train_x, train_y)

# %% [markdown]
# ### Plaintext training

# %%
#Define Linear regression model
class LinearSyNet(sy.Module):
    def __init__(self, torch_ref):
        super(LinearSyNet, self).__init__(torch_ref=torch_ref)
        self.fc1 = self.torch_ref.nn.Linear(13,1)

    def forward(self, x):
        x = self.fc1(x)
        return x

# %%
#Define model, loss function and optimizer
model = LinearSyNet(torch)
criterion = torch.nn.MSELoss(reduction='mean') 
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
#Training Loop
for epoch in range(epochs):
  running_loss = 0.0
  for index in range(0,len(train_batches)):
    # Clear gradient buffers because we don't want any gradient from previous epoch to carry forward, dont want to cummulate gradients
    optimizer.zero_grad()

    # get output from the model, given the inputs
    outputs = model(train_batches[index][0]).reshape([-1])

    # get loss for the predicted output
    loss = criterion(outputs,train_batches[index][1])
    running_loss += loss
    # get gradients w.r.t to parameters
    loss.backward()

    # update parameters
    optimizer.step()
    
  test_accuracy = criterion(model(test_x).reshape([-1]),test_y)
  if((epoch%50)==0):
     print(f"Epoch {epoch}/{epochs}  Running Loss : {running_loss.item()/batch_size} and test loss: {test_accuracy.item()}")
# Out:
# Epoch 0/300  Running Loss : 1006.2069091796875 and test loss: 355.1054992675781
# Epoch 50/300  Running Loss : 53.09187698364258 and test loss: 110.3436050415039
# Epoch 100/300  Running Loss : 43.0759391784668 and test loss: 48.66814422607422
# Epoch 150/300  Running Loss : 41.09862518310547 and test loss: 30.31635856628418
# Epoch 200/300  Running Loss : 40.13597869873047 and test loss: 23.175142288208008
# Epoch 250/300  Running Loss : 39.59026336669922 and test loss: 20.673261642456055

# %% [markdown]
# ### Plaintext Inference

# %%
#Perform inference in plaintext
start_time=time.time()
plaintext_predictions = model(test_x).reshape([-1])
end_time=time.time()

# %%
#Calculate inference time and MSELoss
print("MSE Loss: ",criterion(plaintext_predictions,test_y).item())
print("Inference time: ",str(end_time-start_time),"s")
# Out:
# MSE Loss:  20.229232788085938
# Inference time:  0.001733541488647461 s

# %% [markdown]
# ### Encrypted Inference

# %%
#SyMPC imports required for encrypted inference
import sympc
from sympc.session import Session
from sympc.session import SessionManager
from sympc.tensor import MPCTensor
from sympc.protocol import FSS,Falcon
# from sympc.protocol import Falcon,FSS

# %%
def get_clients(n_parties):
  #Generate required number of syft clients and return them.

  parties=[]
  for index in range(n_parties): 
      parties.append(sy.VirtualMachine(name = "worker"+str(index)).get_root_client())

  return parties

# %%
def split_send(data,session):
    """Splits data into number of chunks equal to number of parties and distributes it to respective 
       parties.
    """
    data_pointers = []
    
    split_size = int(len(data)/len(session.parties))+1
    for index in range(0,len(session.parties)):
        ptr=data[index*split_size:index*split_size+split_size].share(session=session)
        data_pointers.append(ptr)
        
    return data_pointers

# %%
def inference(n_clients,protocol=None):
    
  # Get VM clients 
  parties=get_clients(n_clients)

  # Setup the session for the computation
  if(protocol):
     session = Session(parties = parties,protocol = protocol)
  else:
     session = Session(parties = parties)
        
  SessionManager.setup_mpc(session)

  #Split data and send data to clients
  pointers = split_send(test_x,session)

  #Encrypt model 
  mpc_model = model.share(session)

  #Encrypt test data
  #test_data=MPCTensor(secret=test_x, session = session)

  #Perform inference and measure time taken
  start_time = time.time()
    
  results = []
    
  for ptr in pointers:
     encrypted_results = mpc_model(ptr)
     plaintext_results = encrypted_results.reconstruct()
     results.append(plaintext_results)
        
  end_time = time.time()

  print(f"Time for inference: {end_time-start_time}s")
    
  predictions = torch.cat(results).reshape([-1])

  #Calculate Loss
  print("MSE Loss: ",criterion(predictions,test_y).item())
    
  return predictions

# %%
predictions=inference(3, Falcon("semi-honest"))
# Out:
# Time for inference: 0.2723851203918457s
# MSE Loss:  20.22910499572754

# %%
for index in range(0,101):
    print(f"Index {index}")
    print(f"Encrypted Prediction Output {predictions[index].item()}")
    print(f"Plaintext Prediction Output {plaintext_predictions[index].item()}")
    print(f"Expected Prediction: {test_y[index]}")
    print("\n")
# Out:
# Index 0
# Encrypted Prediction Output 2.598541259765625
# Plaintext Prediction Output 2.59842848777771
# Expected Prediction: 5.0
#
#
# Index 1
# Encrypted Prediction Output 4.947998046875
# Plaintext Prediction Output 4.9478864669799805
# Expected Prediction: 11.899999618530273
#
#
# Index 2
# Encrypted Prediction Output 19.206314086914062
# Plaintext Prediction Output 19.206314086914062
# Expected Prediction: 27.899999618530273
#
#
# Index 3
# Encrypted Prediction Output 12.046829223632812
# Plaintext Prediction Output 12.04680061340332
# Expected Prediction: 17.200000762939453
#
#
# Index 4
# Encrypted Prediction Output 19.068893432617188
# Plaintext Prediction Output 19.06889533996582
# Expected Prediction: 27.5
#
#
# Index 5
# Encrypted Prediction Output 11.845855712890625
# Plaintext Prediction Output 11.845837593078613
# Expected Prediction: 15.0
#
#
# Index 6
# Encrypted Prediction Output 16.331619262695312
# Plaintext Prediction Output 16.331565856933594
# Expected Prediction: 17.200000762939453
#
#
# Index 7
# Encrypted Prediction Output -1.2619476318359375
# Plaintext Prediction Output -1.262048602104187
# Expected Prediction: 17.899999618530273
#
#
# Index 8
# Encrypted Prediction Output 8.829071044921875
# Plaintext Prediction Output 8.828988075256348
# Expected Prediction: 16.299999237060547
#
#
# Index 9
# Encrypted Prediction Output -8.984954833984375
# Plaintext Prediction Output -8.985016822814941
# Expected Prediction: 7.0
#
#
# Index 10
# Encrypted Prediction Output 8.7381591796875
# Plaintext Prediction Output 8.73814582824707
# Expected Prediction: 7.199999809265137
#
#
# Index 11
# Encrypted Prediction Output 13.492782592773438
# Plaintext Prediction Output 13.492774963378906
# Expected Prediction: 7.5
#
#
# Index 12
# Encrypted Prediction Output 4.6313323974609375
# Plaintext Prediction Output 4.631237506866455
# Expected Prediction: 10.399999618530273
#
#
# Index 13
# Encrypted Prediction Output 1.1719512939453125
# Plaintext Prediction Output 1.1718615293502808
# Expected Prediction: 8.800000190734863
#
#
# Index 14
# Encrypted Prediction Output 15.077499389648438
# Plaintext Prediction Output 15.077478408813477
# Expected Prediction: 8.399999618530273
#
#
# Index 15
# Encrypted Prediction Output 19.794540405273438
# Plaintext Prediction Output 19.794565200805664
# Expected Prediction: 16.700000762939453
#
#
# Index 16
# Encrypted Prediction Output 18.351791381835938
# Plaintext Prediction Output 18.351741790771484
# Expected Prediction: 14.199999809265137
#
#
# Index 17
# Encrypted Prediction Output 17.5194091796875
# Plaintext Prediction Output 17.519384384155273
# Expected Prediction: 20.799999237060547
#
#
# Index 18
# Encrypted Prediction Output 12.929977416992188
# Plaintext Prediction Output 12.929861068725586
# Expected Prediction: 13.399999618530273
#
#
# Index 19
# Encrypted Prediction Output 14.05157470703125
# Plaintext Prediction Output 14.051501274108887
# Expected Prediction: 11.699999809265137
#
#
# Index 20
# Encrypted Prediction Output 9.263031005859375
# Plaintext Prediction Output 9.262911796569824
# Expected Prediction: 8.300000190734863
#
#
# Index 21
# Encrypted Prediction Output 15.677749633789062
# Plaintext Prediction Output 15.677682876586914
# Expected Prediction: 10.199999809265137
#
#
# Index 22
# Encrypted Prediction Output 12.41693115234375
# Plaintext Prediction Output 12.416802406311035
# Expected Prediction: 10.899999618530273
#
#
# Index 23
# Encrypted Prediction Output 14.406753540039062
# Plaintext Prediction Output 14.406648635864258
# Expected Prediction: 11.0
#
#
# Index 24
# Encrypted Prediction Output 13.099929809570312
# Plaintext Prediction Output 13.099875450134277
# Expected Prediction: 9.5
#
#
# Index 25
# Encrypted Prediction Output 17.889328002929688
# Plaintext Prediction Output 17.889272689819336
# Expected Prediction: 14.5
#
#
# Index 26
# Encrypted Prediction Output 18.490447998046875
# Plaintext Prediction Output 18.490385055541992
# Expected Prediction: 14.100000381469727
#
#
# Index 27
# Encrypted Prediction Output 21.785858154296875
# Plaintext Prediction Output 21.78586196899414
# Expected Prediction: 16.100000381469727
#
#
# Index 28
# Encrypted Prediction Output 18.122802734375
# Plaintext Prediction Output 18.122802734375
# Expected Prediction: 14.300000190734863
#
#
# Index 29
# Encrypted Prediction Output 16.310043334960938
# Plaintext Prediction Output 16.309974670410156
# Expected Prediction: 11.699999809265137
#
#
# Index 30
# Encrypted Prediction Output 13.8585205078125
# Plaintext Prediction Output 13.858477592468262
# Expected Prediction: 13.399999618530273
#
#
# Index 31
# Encrypted Prediction Output 15.123672485351562
# Plaintext Prediction Output 15.123602867126465
# Expected Prediction: 9.600000381469727
#
#
# Index 32
# Encrypted Prediction Output 8.705963134765625
# Plaintext Prediction Output 8.705869674682617
# Expected Prediction: 8.699999809265137
#
#
# Index 33
# Encrypted Prediction Output 4.128082275390625
# Plaintext Prediction Output 4.127933502197266
# Expected Prediction: 8.399999618530273
#
#
# Index 34
# Encrypted Prediction Output 12.437973022460938
# Plaintext Prediction Output 12.437928199768066
# Expected Prediction: 12.800000190734863
#
#
# Index 35
# Encrypted Prediction Output 11.262176513671875
# Plaintext Prediction Output 11.26208209991455
# Expected Prediction: 10.5
#
#
# Index 36
# Encrypted Prediction Output 17.386856079101562
# Plaintext Prediction Output 17.386857986450195
# Expected Prediction: 17.100000381469727
#
#
# Index 37
# Encrypted Prediction Output 19.1834716796875
# Plaintext Prediction Output 19.18338394165039
# Expected Prediction: 18.399999618530273
#
#
# Index 38
# Encrypted Prediction Output 18.201431274414062
# Plaintext Prediction Output 18.201435089111328
# Expected Prediction: 15.399999618530273
#
#
# Index 39
# Encrypted Prediction Output 11.058746337890625
# Plaintext Prediction Output 11.05868148803711
# Expected Prediction: 10.800000190734863
#
#
# Index 40
# Encrypted Prediction Output 12.481948852539062
# Plaintext Prediction Output 12.48193073272705
# Expected Prediction: 11.800000190734863
#
#
# Index 41
# Encrypted Prediction Output 18.257659912109375
# Plaintext Prediction Output 18.257610321044922
# Expected Prediction: 14.899999618530273
#
#
# Index 42
# Encrypted Prediction Output 18.315399169921875
# Plaintext Prediction Output 18.315385818481445
# Expected Prediction: 12.600000381469727
#
#
# Index 43
# Encrypted Prediction Output 17.407333374023438
# Plaintext Prediction Output 17.407258987426758
# Expected Prediction: 14.100000381469727
#
#
# Index 44
# Encrypted Prediction Output 17.511077880859375
# Plaintext Prediction Output 17.511070251464844
# Expected Prediction: 13.0
#
#
# Index 45
# Encrypted Prediction Output 17.862594604492188
# Plaintext Prediction Output 17.862573623657227
# Expected Prediction: 13.399999618530273
#
#
# Index 46
# Encrypted Prediction Output 20.022079467773438
# Plaintext Prediction Output 20.02203369140625
# Expected Prediction: 15.199999809265137
#
#
# Index 47
# Encrypted Prediction Output 18.963424682617188
# Plaintext Prediction Output 18.963417053222656
# Expected Prediction: 16.100000381469727
#
#
# Index 48
# Encrypted Prediction Output 23.354583740234375
# Plaintext Prediction Output 23.354625701904297
# Expected Prediction: 17.799999237060547
#
#
# Index 49
# Encrypted Prediction Output 16.335922241210938
# Plaintext Prediction Output 16.33589744567871
# Expected Prediction: 14.899999618530273
#
#
# Index 50
# Encrypted Prediction Output 17.047653198242188
# Plaintext Prediction Output 17.047609329223633
# Expected Prediction: 14.100000381469727
#
#
# Index 51
# Encrypted Prediction Output 13.660324096679688
# Plaintext Prediction Output 13.66019058227539
# Expected Prediction: 12.699999809265137
#
#
# Index 52
# Encrypted Prediction Output 13.719650268554688
# Plaintext Prediction Output 13.719523429870605
# Expected Prediction: 13.5
#
#
# Index 53
# Encrypted Prediction Output 17.746734619140625
# Plaintext Prediction Output 17.746694564819336
# Expected Prediction: 14.899999618530273
#
#
# Index 54
# Encrypted Prediction Output 18.82342529296875
# Plaintext Prediction Output 18.823326110839844
# Expected Prediction: 20.0
#
#
# Index 55
# Encrypted Prediction Output 20.072280883789062
# Plaintext Prediction Output 20.072223663330078
# Expected Prediction: 16.399999618530273
#
#
# Index 56
# Encrypted Prediction Output 20.891311645507812
# Plaintext Prediction Output 20.89126205444336
# Expected Prediction: 17.700000762939453
#
#
# Index 57
# Encrypted Prediction Output 20.281753540039062
# Plaintext Prediction Output 20.2817440032959
# Expected Prediction: 19.5
#
#
# Index 58
# Encrypted Prediction Output 23.368865966796875
# Plaintext Prediction Output 23.36896324157715
# Expected Prediction: 20.200000762939453
#
#
# Index 59
# Encrypted Prediction Output 20.306060791015625
# Plaintext Prediction Output 20.305932998657227
# Expected Prediction: 21.399999618530273
#
#
# Index 60
# Encrypted Prediction Output 18.056411743164062
# Plaintext Prediction Output 18.05634880065918
# Expected Prediction: 19.899999618530273
#
#
# Index 61
# Encrypted Prediction Output 15.109817504882812
# Plaintext Prediction Output 15.10971736907959
# Expected Prediction: 19.0
#
#
# Index 62
# Encrypted Prediction Output 16.146926879882812
# Plaintext Prediction Output 16.146848678588867
# Expected Prediction: 19.100000381469727
#
#
# Index 63
# Encrypted Prediction Output 15.38970947265625
# Plaintext Prediction Output 15.389631271362305
# Expected Prediction: 19.100000381469727
#
#
# Index 64
# Encrypted Prediction Output 17.169570922851562
# Plaintext Prediction Output 17.16948127746582
# Expected Prediction: 20.100000381469727
#
#
# Index 65
# Encrypted Prediction Output 19.689971923828125
# Plaintext Prediction Output 19.689931869506836
# Expected Prediction: 19.899999618530273
#
#
# Index 66
# Encrypted Prediction Output 22.427734375
# Plaintext Prediction Output 22.427698135375977
# Expected Prediction: 19.600000381469727
#
#
# Index 67
# Encrypted Prediction Output 22.284896850585938
# Plaintext Prediction Output 22.28493881225586
# Expected Prediction: 23.200000762939453
#
#
# Index 68
# Encrypted Prediction Output 26.019805908203125
# Plaintext Prediction Output 26.019874572753906
# Expected Prediction: 29.799999237060547
#
#
# Index 69
# Encrypted Prediction Output 15.081527709960938
# Plaintext Prediction Output 15.081480979919434
# Expected Prediction: 13.800000190734863
#
#
# Index 70
# Encrypted Prediction Output 15.079086303710938
# Plaintext Prediction Output 15.0790433883667
# Expected Prediction: 13.300000190734863
#
#
# Index 71
# Encrypted Prediction Output 20.178024291992188
# Plaintext Prediction Output 20.178028106689453
# Expected Prediction: 16.700000762939453
#
#
# Index 72
# Encrypted Prediction Output 9.372970581054688
# Plaintext Prediction Output 9.372875213623047
# Expected Prediction: 12.0
#
#
# Index 73
# Encrypted Prediction Output 18.297088623046875
# Plaintext Prediction Output 18.297067642211914
# Expected Prediction: 14.600000381469727
#
#
# Index 74
# Encrypted Prediction Output 20.887725830078125
# Plaintext Prediction Output 20.887718200683594
# Expected Prediction: 21.399999618530273
#
#
# Index 75
# Encrypted Prediction Output 22.94989013671875
# Plaintext Prediction Output 22.94991683959961
# Expected Prediction: 23.0
#
#
# Index 76
# Encrypted Prediction Output 27.071380615234375
# Plaintext Prediction Output 27.07149887084961
# Expected Prediction: 23.700000762939453
#
#
# Index 77
# Encrypted Prediction Output 28.784210205078125
# Plaintext Prediction Output 28.784278869628906
# Expected Prediction: 25.0
#
#
# Index 78
# Encrypted Prediction Output 20.658233642578125
# Plaintext Prediction Output 20.658241271972656
# Expected Prediction: 21.799999237060547
#
#
# Index 79
# Encrypted Prediction Output 19.310882568359375
# Plaintext Prediction Output 19.310827255249023
# Expected Prediction: 20.600000381469727
#
#
# Index 80
# Encrypted Prediction Output 22.43292236328125
# Plaintext Prediction Output 22.432903289794922
# Expected Prediction: 21.200000762939453
#
#
# Index 81
# Encrypted Prediction Output 19.255081176757812
# Plaintext Prediction Output 19.25501823425293
# Expected Prediction: 19.100000381469727
#
#
# Index 82
# Encrypted Prediction Output 20.97418212890625
# Plaintext Prediction Output 20.974197387695312
# Expected Prediction: 20.600000381469727
#
#
# Index 83
# Encrypted Prediction Output 12.963531494140625
# Plaintext Prediction Output 12.963438034057617
# Expected Prediction: 15.199999809265137
#
#
# Index 84
# Encrypted Prediction Output 9.055938720703125
# Plaintext Prediction Output 9.055859565734863
# Expected Prediction: 7.0
#
#
# Index 85
# Encrypted Prediction Output 4.0315704345703125
# Plaintext Prediction Output 4.031454086303711
# Expected Prediction: 8.100000381469727
#
#
# Index 86
# Encrypted Prediction Output 15.213302612304688
# Plaintext Prediction Output 15.213207244873047
# Expected Prediction: 13.600000381469727
#
#
# Index 87
# Encrypted Prediction Output 17.685714721679688
# Plaintext Prediction Output 17.685670852661133
# Expected Prediction: 20.100000381469727
#
#
# Index 88
# Encrypted Prediction Output 20.801727294921875
# Plaintext Prediction Output 20.801755905151367
# Expected Prediction: 21.799999237060547
#
#
# Index 89
# Encrypted Prediction Output 20.80322265625
# Plaintext Prediction Output 20.803176879882812
# Expected Prediction: 24.5
#
#
# Index 90
# Encrypted Prediction Output 16.772857666015625
# Plaintext Prediction Output 16.77276039123535
# Expected Prediction: 23.100000381469727
#
#
# Index 91
# Encrypted Prediction Output 13.554885864257812
# Plaintext Prediction Output 13.554839134216309
# Expected Prediction: 19.700000762939453
#
#
# Index 92
# Encrypted Prediction Output 19.330230712890625
# Plaintext Prediction Output 19.330223083496094
# Expected Prediction: 18.299999237060547
#
#
# Index 93
# Encrypted Prediction Output 21.618560791015625
# Plaintext Prediction Output 21.618497848510742
# Expected Prediction: 21.200000762939453
#
#
# Index 94
# Encrypted Prediction Output 18.391189575195312
# Plaintext Prediction Output 18.391151428222656
# Expected Prediction: 17.5
#
#
# Index 95
# Encrypted Prediction Output 20.746002197265625
# Plaintext Prediction Output 20.745935440063477
# Expected Prediction: 16.799999237060547
#
#
# Index 96
# Encrypted Prediction Output 24.560073852539062
# Plaintext Prediction Output 24.560136795043945
# Expected Prediction: 22.399999618530273
#
#
# Index 97
# Encrypted Prediction Output 23.1138916015625
# Plaintext Prediction Output 23.1138916015625
# Expected Prediction: 20.600000381469727
#
#
# Index 98
# Encrypted Prediction Output 29.07122802734375
# Plaintext Prediction Output 29.071273803710938
# Expected Prediction: 23.899999618530273
#
#
# Index 99
# Encrypted Prediction Output 27.461578369140625
# Plaintext Prediction Output 27.461650848388672
# Expected Prediction: 22.0
#
#
# Index 100
# Encrypted Prediction Output 23.150619506835938
# Plaintext Prediction Output 23.150615692138672
# Expected Prediction: 11.899999618530273

# %%
predictions=inference(3,Falcon("malicious"))
# Out:
# Time for inference: 1.6142754554748535s
# MSE Loss:  20.22911262512207

# %%
print('Inference with 3 parties')
predictions=inference(3)
print()
print('Inference with 5 parties')
predictions=inference(5)
# Out:
# Inference with 3 parties
# Time for inference: 0.9718637466430664s
# MSE Loss:  20.227685928344727
#
# Inference with 5 parties
# Time for inference: 2.1683151721954346s
# MSE Loss:  20.227663040161133
